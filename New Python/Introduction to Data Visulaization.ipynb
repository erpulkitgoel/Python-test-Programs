# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000,4), index = pd.date_range('1/1/2000',periods=1000),columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.231346  0.591045  0.500384  0.521267
# 2000-01-02 -1.362621 -0.226475  1.031619  1.837524
# 2000-01-03  0.909920 -0.938505 -0.294071 -2.029477
# 2000-01-04  1.677400 -0.300036 -0.923185  1.460213
# 2000-01-05  0.259568 -0.056394 -0.612311 -0.076341
# 2000-01-06  0.371227  1.423854 -0.438565 -0.785437
# 2000-01-07 -0.489422 -1.110404  2.281006  0.373737
# 2000-01-08 -0.347688 -1.708850  0.501943  0.842657
# 2000-01-09 -0.088024  0.486436 -1.709685 -1.317263
# 2000-01-10 -1.093678  0.997328  1.285850 -0.247105
# 2000-01-11  0.206307 -1.043593  0.269450 -1.688269
# 2000-01-12  1.658434  0.175524  0.990188 -0.191282
# 2000-01-13 -0.592684  0.127894 -1.519140 -0.946054
# 2000-01-14  0.137632  0.805222  0.899492  1.171689
# 2000-01-15  1.162506 -0.073320  0.224144  2.815404
# 2000-01-16  1.802663 -1.711665  1.052477  1.986780
# 2000-01-17  0.623856  0.198579 -1.577316  1.197474
# ...

# %%
df.cumsum().plot()

# %%
df2 = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C', 'D'])

# %%
df2
# Out:
#           A         B         C         D
# 0  0.417171  0.153233  0.721243  0.969289
# 1  0.588404  0.004516  0.551364  0.699423
# 2  0.824433  0.017828  0.701055  0.228592
# 3  0.845756  0.387726  0.225613  0.896742
# 4  0.264263  0.110327  0.970528  0.801980
# 5  0.663376  0.034110  0.513230  0.274201
# 6  0.027393  0.297491  0.045077  0.315688
# 7  0.776447  0.124057  0.050862  0.372511
# 8  0.613132  0.158280  0.268750  0.404716
# 9  0.741547  0.162958  0.193644  0.306121

# %%
df2.plot.bar()

# %%
df4 = pd.DataFrame({'a': [1,2,4,4,4,5,5,6,7,6,]})

df4
# Out:
#    a
# 0  1
# 1  2
# 2  4
# 3  4
# 4  4
# 5  5
# 6  5
# 7  6
# 8  7
# 9  6

# %%
df4.plot.hist(alpha=0.5, bins=3, orientation='horizontal')

# %%
df5 = pd.DataFrame(np.random.rand(10,5), columns=['a','b','c','d','e'])
df5.plot.box()

# %%
df5.describe()
# Out:
#                a          b          c          d          e
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.442500   0.439435   0.500049   0.478693   0.389959
# std     0.262533   0.259401   0.261926   0.340915   0.295847
# min     0.094154   0.112607   0.068755   0.042559   0.030230
# 25%     0.266193   0.212545   0.378079   0.227221   0.177963
# 50%     0.375980   0.473544   0.541322   0.480373   0.316539
# 75%     0.565524   0.532746   0.616129   0.768901   0.644866
# max     0.931818   0.841799   0.889505   0.964676   0.878157

# %%
df6 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
df6
# Out:
#           a         b         c         d
# 0  0.268700  0.403588  0.956542  0.687276
# 1  0.119795  0.487769  0.459085  0.447991
# 2  0.863904  0.847345  0.663217  0.259878
# 3  0.531655  0.647926  0.639660  0.306868
# 4  0.389254  0.716934  0.977788  0.152845
# 5  0.572756  0.299359  0.688185  0.488431
# 6  0.707756  0.168270  0.434417  0.708705
# 7  0.985543  0.045753  0.675884  0.974611
# 8  0.175649  0.305045  0.663159  0.188516
# 9  0.844159  0.786880  0.194115  0.853535

# %%
df6.plot.area()

# %%
df6.plot.area(stacked=False)

# %%
df7 = pd.DataFrame(np.random.rand(1000,2),columns=['a','b'])

df7['b'] = df7['b'] + np.arange(1000)

df7.plot.hexbin(x='a', y='b', gridsize=10)
# Out:
#           a         b
# 0  0.365626  0.049040
# 1  0.982104  0.250011
# 2  0.924976  0.060768
# 3  0.524778  0.530547
# 4  0.699155  0.696607
#           a         b
# 0  0.365626  0.049040
# 1  0.982104  1.250011
# 2  0.924976  2.060768
# 3  0.524778  3.530547
# 4  0.699155  4.696607

# %%
df7.plot.scatter(x='a', y='b')

# %%
df8 = pd.DataFrame(3* np.random.rand(4,2), index=['a','b','c','d'],columns=['x','y'])
df8
# Out:
#           x         y
# a  2.424108  2.729270
# b  1.748167  1.640830
# c  0.625695  0.025338
# d  1.250741  0.929924

# %%
df8.plot.pie('y',subplots=False, figsize=(12,3), autopct='%0.3f')

# %%
df8.plot.pie('x',subplots=False, figsize=(12,3), autopct='%0.3f')

# %%
df9 = pd.DataFrame(np.random.randn(1000,4),columns=['a','b','c','d'])
df9
# Out:
#             a         b         c         d
# 0   -1.284945  0.273771 -2.345489  0.753369
# 1   -1.586847 -1.006174  0.525720  0.551455
# 2    0.557742  0.165776 -0.734111 -1.298247
# 3    0.794048 -0.036266 -1.777118  0.419041
# 4    0.097284  0.279706  0.327743 -1.199752
# 5   -1.342984 -0.194399  0.326646  0.316337
# 6   -0.793868 -0.679782  0.571470  0.599979
# 7    0.947578 -0.502360 -0.486605 -0.269789
# 8   -0.320823 -1.134121  0.869172  1.202751
# 9    0.830639  0.039551  0.662471 -0.024589
# 10   0.563596  0.538695  0.871313 -0.695969
# 11   0.748146  2.036013 -0.115901  0.309297
# 12   1.834881 -0.972424  0.381199  0.721761
# 13   1.148079 -1.025102 -0.531059 -0.637390
# 14  -1.582877  2.002049 -1.035828 -0.737720
# 15   0.608139 -1.319786  1.199777 -1.585323
# 16  -2.005245 -1.022032  0.166631 -0.270680
# 17   3.484000  0.963374  0.628103 -0.741775
# 18   2.654144 -1.597712 -0.645634 -0.124561
# 19   0.092350  0.439749  1.524306  0.705533
# ...

# %%
df9.plot(subplots=True, figsize=(10,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002BE3616C6A0>,
# ...
#       dtype=object)

# %%
ts = pd.Series(np.arange(1000), index=pd.date_range('1/1/2000',periods=1000))
df10 = pd.DataFrame(np.random.randn(1000,4), index=ts.index, columns=list('ABCD'))
df10.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.294704 -1.024325 -0.547262  1.620232
# 2000-01-02  0.623137  0.896420 -2.649161 -1.585104
# 2000-01-03 -0.254480 -0.420207  1.230709 -1.707272
# 2000-01-04  0.244324 -0.832007  0.086109 -0.262145
# 2000-01-05 -0.059424 -1.015573  0.040994  0.940619

# %%
df10.iloc[3].plot(kind='bar')
