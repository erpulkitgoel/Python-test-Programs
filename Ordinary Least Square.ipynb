# %%
import statsmodels.api as sm
from statsmodels.datasets import cancer

# %%
cancer_dat = cancer.load()
# Out:
# C:\Users\pulkit.goel\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\datasets\utils.py:100: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   exog = np.column_stack(data[field] for field in exog_name)

# %%
cancer_dat.data
# Out:
# rec.array([(  1.,   445.), (  0.,   559.), (  3.,   677.), (  4.,   681.),
#            (  3.,   746.), (  4.,   869.), (  1.,   950.), (  5.,   976.),
#            (  5.,  1096.), (  5.,  1098.), (  5.,  1114.), (  7.,  1125.),
#            (  5.,  1236.), (  6.,  1285.), (  3.,  1291.), (  3.,  1318.),
#            (  2.,  1323.), (  8.,  1327.), (  9.,  1438.), (  7.,  1479.),
#            (  4.,  1536.), (  6.,  1598.), (  6.,  1635.), ( 11.,  1667.),
#            (  4.,  1696.), (  7.,  1792.), (  7.,  1795.), (  4.,  1808.),
#            (  6.,  1838.), ( 16.,  1838.), (  3.,  1847.), (  8.,  1933.),
#            (  8.,  1959.), (  4.,  1990.), (  9.,  2003.), ( 10.,  2070.),
#            (  7.,  2091.), (  8.,  2099.), (  5.,  2104.), ( 11.,  2147.),
#            (  4.,  2154.), ( 12.,  2163.), ( 11.,  2172.), (  9.,  2174.),
#            ( 13.,  2183.), ( 17.,  2193.), ( 11.,  2210.), ( 10.,  2212.),
# ...

# %%
X = cancer_dat.exog
Y = cancer_dat.endog

# %%
model = sm.OLS(X,Y)
fit = model.fit()

# %%
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     7161.
# Date:                Mon, 06 May 2019   Prob (F-statistic):          2.09e-211
# Time:                        12:50:57   Log-Likelihood:                -2889.2
# No. Observations:                 301   AIC:                             5780.
# Df Residuals:                     300   BIC:                             5784.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           269.6975      3.187     84.623      0.000     263.426     275.969
# ...
